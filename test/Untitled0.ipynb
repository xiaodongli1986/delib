# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['product', 'random', 'transpose', 'copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
Z, Ez, Qz, q_Hsq_fun, H_residual = Xsfromdata(np.loadtxt('./qz.txt'), [0,1,2,3,4])
Z, Ez_lcdm, Qz_lcdm, q_Hsq_fun_lcdm = Xsfromdata(np.loadtxt('./qz_lcdm.txt'), [0,1,2,3])

logZ = [np.log10(zz) for zz in Z]
logEz = [np.log10(zz) for zz in Ez]
logEz_lcdm = [np.log10(zz) for zz in Ez_lcdm]
Ezrat = [Ez[row]/Ez_lcdm[row] for row in range(len(Z))]

fig, ax = figax(14,5)
ax.grid()
ax.plot(logZ, Qz)
ax.plot(logZ, Qz_lcdm)
fig.show()

fig, ax = figax(14,5)
ax.grid()
ax.plot(logZ, logEz)
ax.plot(logZ, logEz_lcdm)
fig.show()

fig, ax = figax(14,5)
ax.grid()
#ax.plot(logZ, logEz)
#ax.plot(logZ, logEz_lcdm)
ax.plot(logZ, Ezrat)
fig.show()

log_q_Hsq_fun = [log10(xx) for xx in q_Hsq_fun]
log_q_Hsq_fun_lcdm = [log10(xx) for xx in q_Hsq_fun_lcdm]
fig, ax = figax(14,5)
ax.grid()
#ax.plot(logZ, logEz)
#ax.plot(logZ, logEz_lcdm)
ax.plot(logZ, log_q_Hsq_fun)
ax.plot(logZ, log_q_Hsq_fun_lcdm)
fig.show()


fig, ax = figax(14,5)
ax.grid()
#ax.plot(logZ, logEz)
#ax.plot(logZ, logEz_lcdm)
ax.plot(logZ, log_q_Hsq_fun)
ax.plot(logZ, log_q_Hsq_fun_lcdm)
fig.show()

# %%
fig, ax = figax(14,5)
ax.grid()
#ax.plot(logZ, logEz)
#ax.plot(logZ, logEz_lcdm)
ax.plot(logZ, Ezrat)
fig.show()

# %%
[H_residual[row]/Ez[row]/Ez[row] for row in range(len(Ez))]
# Out:
# [-0.00015491325299748352,
#  -0.0002372305803759272,
#  -0.00031963907997707898,
#  -0.00040504155565504745,
#  -0.00050027640113192121,
#  -0.00061170556756850764,
#  -0.00074504891943102199,
#  -0.0009060858592705185,
#  -0.0011012473720297818,
#  -0.0013380542401175879,
#  -0.0016254904584652476,
#  -0.0019743696323979727,
#  -0.0023977420158867602,
#  -0.0029113572698558493,
#  -0.0035342042114488497,
#  -0.0042891513935719499,
#  -0.0052036715936306021,
#  -0.006310699491660199,
#  -0.0076495985499499342,
#  -0.0092672278200162054,
#  -0.011219136485626601,
#  -0.013570791786329547,
#  -0.016398845900007064,
#  -0.019792275332142763,
#  -0.023853261147277573,
#  -0.028697677105854864,
#  -0.034454768296432257,
#  -0.041265720453673514,
#  -0.049280470219336285,
#  -0.05865286728909027,
#  -0.069532759373278977,
#  -0.082055592762991264,
#  -0.096329167555610343,
#  -0.11241769262077932,
#  -0.13032576662142253,
#  -0.14998258238922305,
#  -0.17123112003512495,
# ...

# %%
Z
# Out:
# [6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
#  6.0235510000000003,
# ...
